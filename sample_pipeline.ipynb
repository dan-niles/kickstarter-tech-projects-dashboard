# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings(action="ignore")

# default figure size in this notebook
plt.rcParams['figure.figsize'] = (10, 6)

# %%
df1 = pd.read_csv('Kickstarter.csv', encoding='unicode_escape')
# df2 = pd.read_csv('test.csv')
# df3 = pd.read_csv('expected.csv')

# %% [markdown]
# # Basic info

# %%
df1['category '].unique()
# Out:
# array(['Hardware', 'Gadgets', 'Web', 'Apps', 'Technology', 'Software',
#        'Flight', 'Makerspaces', 'Fabrication Tools', 'Sound',
#        'DIY Electronics', 'Camera Equipment', '3D Printing', 'Wearables',
#        'Space Exploration', 'Robots'], dtype=object)

# %%
df1['status'].unique()
# Out:
# array(['failed', 'canceled', 'successful', 'live', 'suspended',
#        'undefined'], dtype=object)

# %%
df1.drop(df1.loc[df1['status'].isnull()].index, inplace=True)

# %%
df1.head()
# Out:
#                                                name  category   \
# 0                                         Safer Home  Hardware
# 1  Gizbee Unlimited Removable Storage for Your T...   Gadgets
# 2  Diposta - liberating people from their postal ...       Web
# 3                  Best Spray Bottle Ever - SureShot   Gadgets
# 4  Fishtacular - The Ultimate Fishing Tool (Cance...      Apps
#
#          deadline    goal  pledged     status backers
# 0    3/7/2015 5:52   50000        0    failed        0
# 1  25/3/2016 19:30   87000     2030  canceled       15
# 2  23/8/2016 13:18  100000      141    failed        3
# 3   7/3/2015 16:57   25000        3    failed        3
# 4  25/5/2015 20:04   50000    11336  canceled       19

# %%
df1.describe(include='all')
# Out:
#                      name    category       deadline   goal  pledged   status  \
# count                15995       15995          15995  15995    15995   15995
# unique               15979          16          15789    994     6508       6
# top     Project (Canceled)  Technology  1/1/2015 5:59  10000        0  failed
# freq                     3        3560              5   1238     2699   10063
#
#        backers
# count     15995
# unique     1261
# top           0
# freq       2704

# %%
df1.columns
# Out:
# Index(['name ', 'category ', 'deadline ', 'goal ', 'pledged ', 'status',
#        'backers ', 'Unnamed: 7'],
#       dtype='object')

# %%
df1 = df1[['name ', 'category ', 'deadline ', 'goal ', 'pledged ', 'status',
       'backers ']]

# %%
df1.head()
# Out:
#                                                name  category   \
# 0                                         Safer Home  Hardware
# 1  Gizbee Unlimited Removable Storage for Your T...   Gadgets
# 2  Diposta - liberating people from their postal ...       Web
# 3                  Best Spray Bottle Ever - SureShot   Gadgets
# 4  Fishtacular - The Ultimate Fishing Tool (Cance...      Apps
#
#             deadline    goal  pledged     status backers
# 0 2015-03-07 05:52:00   50000        0    failed        0
# 1 2016-03-25 19:30:00   87000     2030  canceled       15
# 2 2016-08-23 13:18:00  100000      141    failed        3
# 3 2015-07-03 16:57:00   25000        3    failed        3
# 4 2015-05-25 20:04:00   50000    11336  canceled       19

# %%
df1.shape
# Out:
# (15995, 7)

# %%
df1['deadline '] = pd.to_datetime(df1['deadline '])

# %%
pd.

# %%
df1.describe(include='all')
# Out:
#                      name    category       deadline   goal  pledged   status  \
# count                16000       16000          16000  16000    16000   16000
# unique               15984          21          15792    999     6513      11
# top     Project (Canceled)  Technology  1/1/2015 5:59  10000        0  failed
# freq                     3        3560              5   1238     2699   10063
# mean                   NaN         NaN            NaN    NaN      NaN     NaN
# std                    NaN         NaN            NaN    NaN      NaN     NaN
# min                    NaN         NaN            NaN    NaN      NaN     NaN
# 25%                    NaN         NaN            NaN    NaN      NaN     NaN
# 50%                    NaN         NaN            NaN    NaN      NaN     NaN
# 75%                    NaN         NaN            NaN    NaN      NaN     NaN
# max                    NaN         NaN            NaN    NaN      NaN     NaN
#
#        backers     Unnamed: 7
# ...

# %%
# Test Data
df2.head()
# Out:
#     x1    x2    x3    x4    x5     x6        x7    x8        x9   x10    x11  \
# 0  7.0  0.53  0.02  53.5   1.0  0.036  0.996494  39.0  0.505150  1.59  107.0
# 1  7.4  0.34  0.30  84.5  14.9  0.037  0.998489  70.0  0.511883  1.02  169.0
# 2  7.0  0.27  0.29  99.5   3.9  0.059  0.998048  28.0  0.549003  0.81  199.0
# 3  5.9  0.25  0.27  40.5   1.5  0.029  0.994585  37.0  0.505150  0.75   81.0
# 4  6.6  0.30  0.24  60.5   1.2  0.034  0.996644  17.0  0.495544  0.90  121.0
#
#        x12   x13   x14   x15
# 0  0.99300  3.20  0.32   9.0
# 1  0.99698  3.25  0.37  10.4
# 2  0.99610  3.54  0.59  10.3
# 3  0.98920  3.20  0.46  12.2
# 4  0.99330  3.13  0.36   9.2

# %%
# for the EDA I will combine expected output with test data
df2['y'] = df3['y']
df2.describe(include='all')
# Out:
#                 x1           x2           x3           x4           x5  \
# count  1626.000000  1631.000000  1619.000000  1633.000000  1618.000000
# mean      6.852737     0.280187     0.329080    69.383344     6.324753
# std       0.819261     0.098805     0.116509    21.040969     4.993304
# min       4.400000     0.080000     0.000000     5.000000     0.600000
# 25%       6.300000     0.210000     0.260000    55.000000     1.700000
# 50%       6.800000     0.270000     0.310000    68.000000     5.100000
# 75%       7.300000     0.330000     0.380000    83.500000     9.800000
# max      10.700000     0.930000     1.000000   220.000000    31.600000
#
#                 x6           x7           x8           x9          x10  \
# count  1627.000000  1627.000000  1620.000000  1631.000000  1629.000000
# mean      0.045794     1.004459    35.250000     0.504159     0.839936
# std       0.022095     0.245073    17.813429     0.035054     0.297791
# ...

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## check for duplicates

# %%
print(f"There are {df1.duplicated().sum()} duplicate rows in training set")
# print(f"There are {df2.duplicated().sum()} duplicate rows in test set")
# Out:
# There are 10127 duplicate rows in training set

# %%
ignore = [col for col in train_clinical.columns if col not in ['visit_id','patient_id']]
print(f"There are {train_clinical.duplicated(subset= ignore).sum()} duplicate rows in training set")
train_clinical.loc[train_clinical.duplicated(subset= ignore, keep=False), :]
# Out:
# There are 0 duplicate rows in training set
# Empty DataFrame
# Columns: [Patient_ID, Pregncies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome]
# Index: []

# %%
dataset.drop_duplicates(subset=[ignore], inplace=True)
dataset.describe()
# Out:
#        Patient_ID   Pregncies     Glucose  BloodPressure  SkinThickness  \
# count  768.000000  766.000000  766.000000     764.000000     764.000000
# mean   384.500000    3.828982  120.472585      67.666230      20.509162
# std    221.846794    3.392532   33.157633      43.262736      15.978891
# min      1.000000   -6.000000 -129.000000   -1000.000000       0.000000
# 25%    192.750000    1.000000   99.000000      62.000000       0.000000
# 50%    384.500000    3.000000  117.000000      72.000000      23.000000
# 75%    576.250000    6.000000  140.000000      80.000000      32.000000
# max    768.000000   17.000000  199.000000     122.000000      99.000000
#
#           Insulin         BMI  DiabetesPedigreeFunction         Age  \
# count  765.000000  766.000000                765.000000  764.000000
# mean    79.929412   32.001044                  0.472037   33.243455
# std    115.377211    7.889997                  0.331708   11.782360
# ...

# %% [markdown]
# ## test if each column has 99% similar values

# %%
# test if each column has 99% similar values
num_rows = len(dataset)

for col in dataset.columns:
    cnts = dataset[col].value_counts(dropna=False)
    top_pct = (cnts/num_rows).iloc[0]
    
    if top_pct > 0.999:
        print('{0}: {1:.2f}%'.format(col, top_pct*100))
        print(cnts)
        print()

# %% [markdown]
# ## check for categorical features

# %%
df1.info()

# %%
df1.nunique()
# Out:
# name          15984
# category         21
# deadline      15792
# goal            999
# pledged        6513
# status           11
# backers        1263
# Unnamed: 7        5
# dtype: int64

# %% [markdown]
# ## data types

# %%
df1.dtypes
# Out:
# x1     float64
# x2     float64
# x3     float64
# x4     float64
# x5     float64
# x6     float64
# x7     float64
# x8     float64
# x9     float64
# x10    float64
# x11    float64
# x12    float64
# x13    float64
# x14    float64
# x15    float64
# y        int64
# dtype: object

# %% [markdown]
# Therefore, all features can be considered as continuous, except the target, therefore let's head in the way for a classification model, rather than a regression model

# %% [markdown]
# ## Missing vals

# %%
print(f'The train data {df1.shape}')
print('Missing count:')
print(df1.isna().sum())
print('Missing Percentage: descending order')
print(np.round(100*df1.isna().sum()/len(df1),2).sort_values(ascending=False))
plt.figure(figsize=(10,15))
print(sns.heatmap(df1.isnull(),yticklabels=False,cbar=False,cmap='Paired'))
# Out:
# The train data (15995, 7)
# Missing count:
# name         0
# category     0
# deadline     0
# goal         0
# pledged      0
# status       0
# backers      0
# dtype: int64
# Missing Percentage: descending order
# name         0.0
# category     0.0
# deadline     0.0
# goal         0.0
# pledged      0.0
# status       0.0
# backers      0.0
# dtype: float64
# Axes(0.125,0.11;0.775x0.77)

# %%
print(f'The test data {df2.shape}')
print('Missing count:')
print(df2.isna().sum())
print('Missing Percentage: descending order')
print(np.round(100*df2.isna().sum()/len(df2),2).sort_values(ascending=False))
plt.figure(figsize=(10,15))
print(sns.heatmap(df2.isnull(),yticklabels=False,cbar=False,cmap='Paired'))
# Out:
# The test data (1633, 16)
# Missing count:
# x1     0
# x2     0
# x3     0
# x4     0
# x5     0
# x6     0
# x7     0
# x8     0
# x9     0
# x10    0
# x11    0
# x12    0
# x13    0
# x14    0
# x15    0
# y      0
# dtype: int64
# Missing Percentage: descending order
# x1     0.0
# x2     0.0
# x3     0.0
# x4     0.0
# x5     0.0
# x6     0.0
# x7     0.0
# x8     0.0
# x9     0.0
# x10    0.0
# x11    0.0
# x12    0.0
# x13    0.0
# x14    0.0
# x15    0.0
# y      0.0
# dtype: float64
# Axes(0.125,0.11;0.775x0.77)

# %% [markdown]
# ### abnormal values

# %%
df = train_clinical.drop(columns = ['patient_id', 'visit_id' ])
plt.figure(figsize=(20,20))
for i,col in enumerate(df.columns,1):
    plt.subplot(3,3,i)
    plt.title(f"Distribution of {col} Data")
    sns.histplot(df[col],kde=True)
    plt.tight_layout()
    plt.plot()

# %%
plt.figure(figsize=(20,20))
for i,col in enumerate(dataset.columns,1):
    # ignore the target variable
    if col == 'Outcome' or col == 'Patient_ID':
        continue
    plt.subplot(4,3,i)
    plt.title(f"Box plot of {col} Data")
    sns.boxplot(dataset[col])
    plt.tight_layout()
    plt.plot()

# %%
# Pregnancies, Glucose, BloodPressure have negative values, and
# SkinThickness, Insulin, BMI has 0 values which are not possible
# Therfore assume that these values are missing values and replace them with NaN
for col in ['Pregncies', 'Glucose', 'BloodPressure']:
    dataset.loc[dataset[col] < 0, col] = np.NaN
# Pregnancies can have 0 values, so do not replace 0 values with NaN
dataset[['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI']] = dataset[['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI']].replace(0, np.NaN)
# from analyzing the missing value ratios, insulin has 48.70% missing values, so better to drop the column but since the assignment specifically asks to replace the values without dropping any data, we will replace the missing values with the median

# %% [markdown]
# ### Try replacing missing values with median(since metric, continuous data) grouped by the target

# %%
# insert median groupby y value for missing values
missing_cols = df1.columns[df1.isnull().any()]
for col in missing_cols:
    df1[col] = df1.groupby('y')[col].transform(lambda x: x.fillna(x.median()))

# %%
# insert median groupby y value for missing values
missing_cols = df2.columns[df2.isnull().any()]
for col in missing_cols:
    df2[col] = df2.groupby('y')[col].transform(lambda x: x.fillna(x.median()))

# %%
# # insert median values for missing values
# # get missing values columns and fill them with median
# missing_cols = df1.columns[df1.isnull().any()]
# # Fill missing values with median
# for col in missing_cols:
#     df1[col].fillna(df1[col].median(), inplace=True)

# %%
# # insert median values for missing values
# # get missing values columns and fill them with median
# missing_cols = df2.columns[df2.isnull().any()]
# # Fill missing values with median
# for col in missing_cols:
#     df2[col].fillna(df2[col].median(), inplace=True)

# %% [markdown]
# ### Imputing values

# %% [markdown]
# ### KNN imputer

# %%
from sklearn.impute import KNNImputer

# Select the variables with missing values
cols_to_impute = train_clinical.columns[train_clinical.isnull().any()]


# Impute missing values using KNN imputation
imputer = KNNImputer(n_neighbors=5)
imputed_values = imputer.fit_transform(cols_to_impute)

# Replace original variables with imputed values
train_clinical[train_clinical] = imputed_values

# %%
from sklearn.impute import KNNImputer

cols_to_impute = dataset.columns[dataset.isnull().any()]

# Perform KNN imputation grouped by Outcome column
for col in cols_to_impute:
    groupby_col = 'Outcome'
    groups = dataset.groupby(groupby_col)
    for name, group in groups:
        # Create a KNN imputer object with n_neighbors=3
        knn_imp = KNNImputer(n_neighbors=3)

        # Subset the data for the current group and column
        subset_data = group[[col]]

        # Fit/transform the KNN imputer on the subset data
        subset_data_imputed = knn_imp.fit_transform(subset_data)

        # Assign the imputed values back to the original dataframe
        diabetes_knn_imputed.loc[group.index, col] = subset_data_imputed.ravel()
# Out:
# ---------------------------------------------------------------------------
#
# ModuleNotFoundError                       Traceback (most recent call last)
#
# <ipython-input-76-e4be30190e81> in <module>
#
# ----> 1 from sklearn.impute import KNNImputer
#
#       2
#
#       3 cols_to_impute = dataset.columns[dataset.isnull().any()]
#
#       4
#
#       5 # Perform KNN imputation grouped by Outcome column
#
#
#
# ModuleNotFoundError: No module named 'sklearn'

# %% [markdown]
# ## Outliers

# %%
sns.pairplot(df1, hue='y')

# %%
num_rows=len(dataset.columns)//(len(dataset.columns)//2)
num_cols=len(dataset.columns)//2
fig, axs = plt.subplots(nrows=num_rows, ncols=num_cols, figsize=(20, 12)) # 15 plots in total

for i, col in enumerate(dataset.columns):
    if col == 'Outcome' or col == 'Patient_ID':
        continue
    sns.boxplot(x='Outcome', y=col, data=dataset, ax=axs[i//num_cols, i%num_cols])
    axs[i//num_cols, i%num_cols].set_title(f'Box plot of {col} and y')

plt.tight_layout()
plt.show()

# %%
# for col in df1.columns:
#     plt.figure(figsize=(25,5))
#     sns.countplot(df1[col])
#     plt.title(f'histogram of {col}')
#     plt.show()

# %% [markdown]
# ### median impute

# %%
# for unique values in y and x1 out of quantile 0.25 and 0.75, replace with upper or lower tail
target = 'Outcome'
cols = ['Glucose', 'BloodPressure', 'SkinThickness', 'DiabetesPedigreeFunction', 'Insulin', 'Pregncies', 'BMI']
for i,x in enumerate(cols):
    q1 = dataset[x].quantile(0.2)
    q3 = dataset[x].quantile(0.8)
    iqr = q3-q1
    Lower_tail = q1 - 1.5 * iqr
    Upper_tail = q3 + 1.5 * iqr
    print(f'{x} \n Lower_tail: {Lower_tail}, Upper_tail: {Upper_tail}  \n outliers count: {dataset[(dataset[x] < Lower_tail) | (dataset[x] > Upper_tail)].shape[0]} \n outliers: {dataset[(dataset[x] < Lower_tail) | (dataset[x] > Upper_tail)][x].unique()}')
    print('------------------------------------')
    # median = dataset[x].median()
    # dataset.loc[(dataset[x] < Lower_tail) | (dataset[x] > Upper_tail), x] = median
    # for j in dataset[x]:
    #     if j> Upper_tail:
    #         dataset[x] = dataset[x].replace(j, Upper_tail)
    #     elif j < Lower_tail:
    #         dataset[x] = dataset[x].replace(j, Lower_tail)

# %%
# print the median of x1 for each y
for i in df1.columns:
    if i == 'y':
        continue
    print(f'The medians for {i} are:',list(df1.groupby('y')[i].median()))
# Out:
# The medians for x1 are: [7.2, 6.9, 6.8, 6.8, 6.7, 6.7, 7.1]
# The medians for x2 are: [0.245, 0.35, 0.28, 0.25, 0.25, 0.275, 0.27]
# The medians for x3 are: [0.34, 0.3, 0.32, 0.32, 0.31, 0.325, 0.36]
# The medians for x4 are: [72.75, 54.0, 76.25, 65.5, 60.0, 59.5, 59.5]
# The medians for x5 are: [4.85, 3.85, 6.8, 4.9, 3.2, 4.2, 2.2]
# The medians for x6 are: [0.039, 0.046, 0.047, 0.042, 0.036, 0.035, 0.031]
# The medians for x7 are: [0.9974718035, 0.997196069, 0.997592101, 0.996694537, 0.995791143, 0.99559781, 0.995138181]
# The medians for x8 are: [26.0, 17.0, 35.0, 34.0, 33.0, 34.0, 28.0]
# The medians for x9 are: [0.501039813, 0.498310554, 0.499687083, 0.503790683, 0.506505032, 0.509202522, 0.515873844]
# The medians for x10 are: [0.735, 1.05, 0.84, 0.75, 0.75, 0.825, 0.81]
# The medians for x11 are: [145.5, 108.0, 153.0, 131.0, 120.0, 119.0, 119.0]
# The medians for x12 are: [0.99495, 0.9944, 0.9951650000000001, 0.9934, 0.9916, 0.991215, 0.9903]
# ...

# %%
# Grouped by target
for x in df1.columns:
    for i in df1['y'].unique():
        q1 = df1[(df1['y'] == i)][x].quantile(0.25)
        q3 = df1[(df1['y'] == i)][x].quantile(0.75)
        iqr = q3-q1
        Lower_tail = q1 - 1.5 * iqr
        Upper_tail = q3 + 1.5 * iqr
        med = df1.groupby('y')[x].median()
        for j in df1[(df1['y'] == i)][x]:
            if j> Upper_tail:
                df1[x] = df1[x].replace(j, Upper_tail)
            elif j < Lower_tail:
                df1[x] = df1[x].replace(j, Lower_tail)

# %% [markdown]
# ### z score, median impute

# %%
from scipy import stats
def ZRscore_outlier(df):
    med = np.median(df)
    ma = stats.median_abs_deviation(df)
    for i in df: 
        z = (0.6745*(i-med))/ (np.median(ma))
        if np.abs(z) > 3: 
            out.append(i)
    # print("Outliers:",out)
# ZRscore_outlier(df1_x['LotArea'])
# df1_x = df1.drop(columns=['y'])
for col in df1.columns:
    if col == 'y':
        continue
    out = []
    ZRscore_outlier(df1[col])
    med = np.median(df1[col])
    for i in out:
        df1[col] = df1[col].replace(i, med)

for col in df2.columns:
    if col == 'y':
        continue
    out = []
    ZRscore_outlier(df2[col])
    med = np.median(df2[col])
    for i in out:
        df2[col] = df2[col].replace(i, med)

# %% [markdown]
# ## Transformation

# %% [markdown]
# ### Normalize

# %%
# from sklearn.preprocessing import RobustScaler
# scaler = RobustScaler()
# df1_x =df1.drop(columns=['y'])
# df2_x =df2.drop(columns=['y'])
# feature_names = df1_x.columns
# df1_x = pd.DataFrame(scaler.fit_transform(df1_x), columns=feature_names, index=df1_x.index)
# df2_x = pd.DataFrame(scaler.transform(df2_x), columns=feature_names, index=df2_x.index)
# df1_x['y'] = df1['y']
# df2_x['y'] = df2['y']

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df1_x =df1.drop(columns=['y'])
df2_x =df2.drop(columns=['y'])
feature_names = df1_x.columns
df1_x = pd.DataFrame(scaler.fit_transform(df1_x), columns=feature_names, index=df1_x.index)
df2_x = pd.DataFrame(scaler.transform(df2_x), columns=feature_names, index=df2_x.index)
df1_x['y'] = df1['y']
df2_x['y'] = df2['y']

# %%
# from sklearn.preprocessing import MinMaxScaler

# scaler = MinMaxScaler()
# df1_x =df1.drop(columns=['y'])
# df2_x =df2.drop(columns=['y'])
# feature_names = df1_x.columns
# df1_x = pd.DataFrame(scaler.fit_transform(df1_x), columns=feature_names, index=df1_x.index)
# df2_x = pd.DataFrame(scaler.transform(df2_x), columns=feature_names, index=df2_x.index)
# df1_x['y'] = df1['y']
# df2_x['y'] = df2['y']

# %%
# from sklearn.preprocessing import MaxAbsScaler

# scaler = MaxAbsScaler()
# df1_x = df1.drop(columns=['y'])

# feature_names = df1_x.columns
# df1_x = pd.DataFrame(scaler.fit_transform(df1_x), columns=feature_names)
# df2 = pd.DataFrame(scaler.transform(df2), columns=feature_names)

# # drop original columns from df1 and add the scaled columns
# df1_x['y'] = df1['y']

# for col in df1_x.columns:
#     df1.drop(columns=[col],inplace=True)
#     # df1.copy(df1_x[col])
# df1 = df1_x.copy()

# %%
df1.describe()
# Out:
#                 x1           x2           x3           x4           x5  \
# count  3265.000000  3265.000000  3265.000000  3265.000000  3265.000000
# mean      6.841087     0.271766     0.328738    68.990792     6.364652
# std       0.803068     0.085663     0.091837    21.211475     4.954352
# min       4.300000     0.080000     0.030000     9.500000     0.600000
# 25%       6.300000     0.210000     0.270000    53.500000     1.700000
# 50%       6.800000     0.260000     0.320000    66.500000     5.200000
# 75%       7.300000     0.320000     0.390000    83.500000     9.700000
# max      11.050000     0.720000     0.675000   136.937500    23.500000
#
#                 x6           x7           x8           x9          x10  \
# count  3265.000000  3265.000000  3265.000000  3265.000000  3265.000000
# mean      0.043265     0.996955    34.129862     0.502574     0.815154
# std       0.010681     0.001427    14.433178     0.019560     0.257308
# ...

# %%
df1_x.describe()
# Out:
#                  x1            x2            x3            x4            x5  \
# count  3.265000e+03  3.265000e+03  3.265000e+03  3.265000e+03  3.265000e+03
# mean  -4.809493e-16  2.611489e-17  2.344900e-16 -2.992332e-16 -1.022833e-16
# std    1.000153e+00  1.000153e+00  1.000153e+00  1.000153e+00  1.000153e+00
# min   -3.164711e+00 -2.238956e+00 -3.253429e+00 -2.805081e+00 -1.163731e+00
# 25%   -6.738788e-01 -7.211453e-01 -6.396919e-01 -7.304143e-01 -9.416703e-01
# 50%   -5.117077e-02 -1.373722e-01 -9.516326e-02 -1.174446e-01 -2.351125e-01
# 75%    5.715372e-01  5.631556e-01  6.671768e-01  6.841311e-01  6.733190e-01
# max    5.241847e+00  5.233341e+00  3.770990e+00  3.203790e+00  3.459175e+00
#
#                  x6            x7            x8            x9           x10  \
# count  3.265000e+03  3.265000e+03  3.265000e+03  3.265000e+03  3.265000e+03
# mean  -3.960759e-16  4.786751e-14 -7.508032e-17  3.416699e-16  2.687658e-16
# ...

# %%
df2.describe()
# Out:
#                 x1           x2           x3           x4           x5  \
# count  1633.000000  1633.000000  1633.000000  1633.000000  1633.000000
# mean     -0.012924     0.058896    -0.099698     0.013254    -0.007612
# std       0.938618     0.984320     0.946686     0.963688     0.981148
# min      -2.542003    -2.238956    -2.708901    -2.710778    -1.163731
# 25%      -0.673879    -0.721145    -0.748598    -0.659687    -0.921483
# 50%      -0.051171    -0.020618    -0.204069    -0.046717    -0.275487
# 75%       0.571537     0.679910     0.558271     0.684131     0.663225
# max       2.751015     2.664739     2.518574     2.782374     3.327958
#
#                 x6           x7           x8           x9          x10  \
# count  1633.000000  1633.000000  1633.000000  1633.000000  1633.000000
# mean      0.002687     0.041484     0.053364     0.043499     0.057097
# std       1.002110     1.005261     1.099210     1.032742     0.987120
# ...

# %%
df2_x.describe()
# Out:
#                 x1           x2           x3           x4           x5  \
# count  1633.000000  1633.000000  1633.000000  1633.000000  1633.000000
# mean     -0.012924     0.058896    -0.099698     0.013254    -0.007612
# std       0.938618     0.984320     0.946686     0.963688     0.981148
# min      -2.542003    -2.238956    -2.708901    -2.710778    -1.163731
# 25%      -0.673879    -0.721145    -0.748598    -0.659687    -0.921483
# 50%      -0.051171    -0.020618    -0.204069    -0.046717    -0.275487
# 75%       0.571537     0.679910     0.558271     0.684131     0.663225
# max       2.751015     2.664739     2.518574     2.782374     3.327958
#
#                 x6           x7           x8           x9          x10  \
# count  1633.000000  1633.000000  1633.000000  1633.000000  1633.000000
# mean      0.002687     0.041484     0.053364     0.043499     0.057097
# std       1.002110     1.005261     1.099210     1.032742     0.987120
# ...

# %%
for col in df1_x.columns:
    df1.drop(columns=[col],inplace=True)
df1 = df1_x.copy()

for col in df2_x.columns:
    df2.drop(columns=[col],inplace=True)
df2 = df2_x.copy()

# %% [markdown]
# ## Imbalanced data

# %% [markdown]
# ### SMOTE

# %%
df1.value_counts('y')
# Out:
# y
# 6    1471
# 5     970
# 7     583
# 8     122
# 4     102
# 3      12
# 9       5
# dtype: int64

# %%
X_train_smote=df1.drop(['y'],axis=1)
Y_train_smote=df1['y']
X_train_smote.shape,Y_train_smote.shape
# Out:
# ((3265, 15), (3265,))

# %%
Y_train_smote.value_counts()
# Out:
# 6    1471
# 5     970
# 7     583
# 8     122
# 4     102
# 3      12
# 9       5
# Name: y, dtype: int64

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state = 2, k_neighbors=4)
X_train_res, y_train_res = sm.fit_resample(X_train_smote, Y_train_smote.ravel())

# %%
X_train_res.shape,y_train_res.shape
# Out:
# ((10297, 15), (10297,))

# %%
# create a dataframe
df1 = pd.DataFrame(X_train_res, columns=feature_names)
# add the target variable
df1['y'] = y_train_res

# %%
df1.value_counts('y')
# Out:
# y
# 3    1471
# 4    1471
# 5    1471
# 6    1471
# 7    1471
# 8    1471
# 9    1471
# dtype: int64

# %%
df1.describe()
# Out:
#                  x1            x2            x3            x4            x5  \
# count  10297.000000  10297.000000  10297.000000  10297.000000  10297.000000
# mean       0.171167      0.150768      0.047754     -0.167648     -0.137718
# std        1.079079      1.007000      0.945249      0.981447      0.882800
# min       -3.164711     -2.238956     -3.253429     -2.805081     -1.163731
# 25%       -0.516019     -0.487636     -0.556499     -0.795095     -0.871187
# 50%        0.113968     -0.020618      0.013742     -0.322715     -0.421712
# 75%        0.730171      0.679910      0.738095      0.499541      0.336773
# max        5.241847      5.233341      3.770990      3.203790      3.459175
#
#                  x6            x7            x8            x9           x10  \
# count  10297.000000  10297.000000  10297.000000  10297.000000  10297.000000
# mean      -0.236497     -0.208955     -0.204208      0.148643      0.150710
# ...

# %% [markdown]
# ### ADASYN

# %%
df1.value_counts('y')
# Out:
# y
# 6    1471
# 5     970
# 7     583
# 8     122
# 4     102
# 3      12
# 9       5
# dtype: int64

# %%
X_train_smote=df1.drop(['y'],axis=1)
Y_train_smote=df1['y']
X_train_smote.shape,Y_train_smote.shape
# Out:
# ((3265, 15), (3265,))

# %%
Y_train_smote.value_counts()
# Out:
# 6    1471
# 5     970
# 7     583
# 8     122
# 4     102
# 3      12
# 9       5
# Name: y, dtype: int64

# %%
from imblearn.over_sampling import ADASYN
sm = ADASYN(random_state = 2 , n_neighbors=4)
X_train_res, y_train_res = sm.fit_resample(X_train_smote, Y_train_smote.ravel())

# %%
X_train_res.shape,y_train_res.shape
# Out:
# ((10263, 15), (10263,))

# %%
# create a dataframe
df1 = pd.DataFrame(X_train_res, columns=feature_names)
# add the target variable
df1['y'] = y_train_res

# %%
df1.value_counts('y')
# Out:
# y
# 5    1523
# 3    1476
# 6    1471
# 9    1470
# 8    1456
# 4    1438
# 7    1429
# dtype: int64

# %%
df1.describe()
# Out:
#                  x1            x2            x3            x4            x5  \
# count  10263.000000  10263.000000  10263.000000  10263.000000  10263.000000
# mean       0.159637      0.129588      0.069378     -0.180103     -0.167479
# std        1.066455      0.965875      0.937097      0.979534      0.859779
# min       -3.164711     -2.238956     -3.253429     -2.805081     -1.163731
# 25%       -0.504592     -0.487636     -0.530786     -0.806940     -0.876598
# 50%        0.097989     -0.020618      0.013742     -0.341073     -0.436986
# 75%        0.741498      0.670274      0.762505      0.489449      0.276792
# max        5.241847      5.233341      3.770990      3.203790      3.459175
#
#                  x6            x7            x8            x9           x10  \
# count  10263.000000  10263.000000  10263.000000  10263.000000  10263.000000
# mean      -0.265109     -0.243243     -0.199053      0.164951      0.129643
# ...

# %% [markdown]
# ### SMOTE + ENN

# %%
df1.value_counts('y')
# Out:
# y
# 6    1471
# 5     970
# 7     583
# 8     122
# 4     102
# 3      12
# 9       5
# dtype: int64

# %%
X_train_smote=df1.drop(['y'],axis=1)
Y_train_smote=df1['y']
X_train_smote.shape,Y_train_smote.shape
# Out:
# ((3265, 15), (3265,))

# %%
Y_train_smote.value_counts()
# Out:
# 6    1471
# 5     970
# 7     583
# 8     122
# 4     102
# 3      12
# 9       5
# Name: y, dtype: int64

# %%
from imblearn.combine import SMOTEENN
from imblearn.over_sampling import SMOTE

sm = SMOTE(k_neighbors=4)
sm = SMOTEENN(random_state = 2 , smote=sm)
X_train_res, y_train_res = sm.fit_resample(X_train_smote, Y_train_smote.ravel())

# %%
X_train_res.shape,y_train_res.shape
# Out:
# ((8139, 15), (8139,))

# %%
# create a dataframe
df1 = pd.DataFrame(X_train_res, columns=feature_names)
# add the target variable
df1['y'] = y_train_res

# %%
df1.value_counts('y')
# Out:
# y
# 3    1471
# 9    1471
# 4    1457
# 8    1457
# 7    1174
# 5     815
# 6     294
# dtype: int64

# %%
df1.describe()
# Out:
#                 x1           x2           x3           x4           x5  \
# count  8139.000000  8139.000000  8139.000000  8139.000000  8139.000000
# mean      0.220319     0.213191     0.066497    -0.199128    -0.170704
# std       1.086756     1.003567     0.935229     0.978478     0.845276
# min      -3.164711    -2.005446    -3.253429    -2.805081    -1.143544
# 25%      -0.424796    -0.398417    -0.530786    -0.808203    -0.861194
# 50%       0.178628     0.049843     0.017742    -0.368933    -0.446616
# 75%       0.820620     0.723838     0.770492     0.480251     0.249384
# max       5.241847     5.233341     3.770990     3.203790     2.782899
#
#                 x6           x7           x8           x9          x10  \
# count  8139.000000  8139.000000  8139.000000  8139.000000  8139.000000
# mean     -0.315004    -0.264037    -0.220343     0.179366     0.213472
# std       1.038635     0.991980     1.177077     1.007877     1.002343
# ...

# %% [markdown]
# # EDA

# %% [markdown]
# ## Correlation

# %%
#ploting the heatmap for correlation for original dataset
fig, ax = plt.subplots(figsize=(12,10))         # Sample figsize in inches
dataset_copy = dataset.drop(columns=['y'])
ax = sns.heatmap(dataset_copy.corr(), annot=True, ax=ax, cmap = "coolwarm")

# %%
from sklearn.feature_selection import mutual_info_classif
X = df1.copy()
# target

y = X.pop('y')
scores = mutual_info_classif(X, y)

def plot_mi_scores(scores):
    scores = scores.sort_values(ascending=True)
    width = np.arange(len(scores))
    ticks = list(scores.index)
    plt.barh(width, scores)
    plt.yticks(width, ticks)
    

plt.figure(dpi=100, figsize=(8, 5))
plot_mi_scores(mi_scores.head(20))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[62], line 17
#      13     plt.yticks(width, ticks)
#      16 plt.figure(dpi=100, figsize=(8, 5))
# ---> 17 plot_mi_scores(mi_scores.head(20))
#
# NameError: name 'mi_scores' is not defined

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier()
X = df1.copy()
# target

y = X.pop('y')
clf.fit(X, y)
scores = clf.feature_importances_
# turn the scores into a pandas series
scores = pd.Series(scores, index=X.columns)
def plot_mi_scores(scores):
    scores = scores.sort_values(ascending=True)
    width = np.arange(len(scores))
    ticks = list(scores.index)
    plt.barh(width, scores)
    plt.yticks(width, ticks)
    

plt.figure(dpi=100, figsize=(8, 5))
plot_mi_scores(scores)

# %%
from sklearn.feature_selection import f_classif

# Select continuous features
continuous_features = df1.select_dtypes(include=['float64', 'int64']).columns

# Compute ANOVA F-value and p-value for each continuous feature
f_values, p_values = f_classif(df1[continuous_features], df1['y'])

# Create a dataframe to store the results
results = pd.DataFrame({'Feature': continuous_features, 'F-value': f_values, 'p-value': p_values})

# Sort the results by descending F-value
results.sort_values(by='F-value', ascending=False, inplace=True)

# Print the results
print(results[results['p-value'] < 0.05])
plt.figure(figsize=(10, 6))
plt.barh(results['Feature'], results['F-value'])
plt.xlabel('F-value')
plt.title('ANOVA F-value for Continuous Features')
plt.show()
# Out:
#    Feature     F-value        p-value
# 15       y         inf   0.000000e+00
# 14     x15  128.537839  2.176153e-144
# 11     x12   98.606953  4.707102e-113
# 6       x7   98.576179  5.078943e-113
# 5       x6   57.084467   6.510312e-67
# 10     x11   32.619718   3.306701e-38
# 3       x4   32.457404   5.168798e-38
# 9      x10   27.807386   1.940689e-32
# 1       x2   27.794431   2.011550e-32
# 7       x8   19.896870   6.794902e-23
# 4       x5   18.541833   2.962146e-21
# 8       x9    8.718846   1.973099e-09
# 12     x13    8.670113   2.253788e-09
# 0       x1    6.699157   4.672359e-07

# %%
# from sklearn.feature_selection import mutual_info_regression
# # Utility functions
# def make_mi_scores(X, y):
#     X = X.copy()
#     for colname in X.select_dtypes(["object", "category"]):
#         X[colname], _ = X[colname].factorize()
#     # All discrete features should now have integer dtypes
#     discrete_features = [pd.api.types.is_integer_dtype(t) for t in X.dtypes]
#     mi_scores = mutual_info_regression(X, y, discrete_features=discrete_features, random_state=0)
#     mi_scores = pd.Series(mi_scores, name="MI Scores", index=X.columns)
#     mi_scores = mi_scores.sort_values(ascending=False)
#     return mi_scores


# def plot_mi_scores(scores):
#     scores = scores.sort_values(ascending=True)
#     width = np.arange(len(scores))
#     ticks = list(scores.index)
#     plt.barh(width, scores)
#     plt.yticks(width, ticks)

# X = df1.copy()
# # target

# y = X.pop('y')
# mi_scores = make_mi_scores(X, y)  
# print(mi_scores.head(20))
# # print(mi_scores.tail(20))  # uncomment to see bottom 20

# plt.figure(dpi=100, figsize=(8, 5))
# plot_mi_scores(mi_scores.head(20))
# # plot_mi_scores(mi_scores.tail(20))  # uncomment to see bottom 20

# %%
corr = df1_copy.corr().abs().stack().reset_index().sort_values(0, ascending=False)

corr['pairs'] = list(zip(corr.level_0, corr.level_1))

corr.set_index(['pairs'], inplace = True)

corr.drop(columns=['level_1', 'level_0'], inplace = True)

corr.columns = ['correlation']

corr.drop_duplicates(inplace=True)

corr = corr[corr['correlation']!=1]
corr = corr[corr['correlation']>0.7]

corr = corr.iloc[::2]

print(corr)
# Out:
#             correlation
# pairs
# (x2, x10)      0.999489
# (x11, x4)      0.995589
# (x12, x5)      0.812371
# (x15, x12)     0.746186

# %%
# based on decision tree classifier
# since x2 and x10 are highly correlated, we can drop x2
df1.drop(columns=["x10"],inplace=True)
df2.drop(columns=["x10"],inplace=True)
# since x4 and x11 are highly correlated, we can drop x4(since it has high correlation with other features compared to x11)
df1.drop(columns=["x11"],inplace=True)
df2.drop(columns=["x11"],inplace=True)
# since x5 and x12 are highly correlated, we can drop x12(since it has high correlation with other features compared to x5)
df1.drop(columns=["x12"],inplace=True)
df2.drop(columns=["x12"],inplace=True)

# %%
col_to_drop = ['x2','x4','x5','x12']
for col in col_to_drop:
    df1.drop(columns=[col],inplace=True, axis=1)
    df2.drop(columns=[col],inplace=True, axis=1)

# %%
fig, ax = plt.subplots(figsize=(12,10)) 
ax = sns.heatmap(dataset.corr(), annot=True, ax=ax, cmap = "coolwarm")

# %% [markdown]
# ### skewness

# %%
plt.figure(figsize=(15,10))
for i,col in enumerate(df1.columns,1):
    if col == 'y':
        continue
    plt.subplot(4,3,i)
    plt.title(f"Distribution of {col} Data")
    sns.histplot(df1[col],kde=True)
    plt.tight_layout()
    plt.plot()

# %%
# list of columns to log transform
# cols_to_transform = df1.columns[df1.columns != 'y']
cols_to_transform = ['x5']


# # log transform the columns
df1[cols_to_transform] = np.log1p(df1[cols_to_transform])
# df1[cols_to_transform] = np.log1p(df1[cols_to_transform])
df2[cols_to_transform] = np.log1p(df2[cols_to_transform])
# Plot a comparison

# %%
from scipy.stats import boxcox

cols_to_transform = ['x5']

# # log transform the columns
df1['x5'],l1 = boxcox(df1['x5']+2)
# df1[cols_to_transform] = np.log1p(df1[cols_to_transform])
df2['x5'],l2 = boxcox(df2['x5']+2)

# %%
from sklearn.feature_selection import SelectKBest, f_classif

# assume X is your feature matrix and y is your target variable
# you can choose the number of features to keep using the k parameter
# selector = SelectKBest(score_func=f_classif, k='all')
selector = SelectKBest(score_func=f_classif, k=7)
df1_x = df1.drop(columns=["y"]) # X_train
df1_y = df1["y"] # y_train
# apply the feature selection to your data
X_new = selector.fit_transform(df1_x, df1_y)

# get the scores for each feature
scores = selector.scores_

# get the indices of the selected features
selected_features_indices = selector.get_support(indices=True)

# get the names of the selected features
selected_features_names = df1_x.columns[selected_features_indices]

# print the scores and names of the selected features
for i, score in enumerate(scores[selected_features_indices]):
    print(f"Feature {i+1}: {selected_features_names[i]} - score = {score}")
# Out:
# Feature 1: x2 - score = 27.79443056624984
# Feature 2: x4 - score = 32.45740413085052
# Feature 3: x5 - score = 14.075855358385416
# Feature 4: x6 - score = 57.084466652317694
# Feature 5: x7 - score = 98.57617873233538
# Feature 6: x8 - score = 19.896869707493487
# Feature 7: x15 - score = 128.53783909476667

# %%
# drop other columns
for col in df1_x.columns:
    if col not in selected_features_names:
        df1.drop(columns=[col],inplace=True, axis=1)
        df2.drop(columns=[col],inplace=True, axis=1)

# %% [markdown]
# # Split

# %%
dataset_x = dataset.drop(columns=["y"]) # X_train
dataset_y = dataset["y"] # y_train

df2_x = df2.drop(columns=["y"]) # X_test
df2_y = df2["y"] # y_test

# %% [markdown]
# # Compare models

# %% [markdown]
# # different models test -- regression

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.dummy import DummyRegressor
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet, SGDRegressor
from sklearn.kernel_ridge import KernelRidge
from sklearn.svm import LinearSVR, SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, BaggingRegressor, AdaBoostRegressor, ExtraTreesRegressor
import lightgbm as lgb
import xgboost as xgb
import time
# Loop through each label   
for label in target:
    print('#######################################################')
    print(f'model {label}')
    # Merge the label 'visit_id', 'patient_id', 'visit_month' and label columns from `train_clinical` 
    # data frame to `pro_prep_df` data frame on the `visit_id` column.
    dataset_df = pro_pep_df.merge(train_clinical[['visit_id', 'patient_id', 'visit_month', label]], on = ['visit_id'], how = 'left')

    # Drop null value label rows
    dataset_df = dataset_df.dropna(subset=[label])
    
    # Make a new copy of the FEATURES list we created previously. Add `label` to it.
    feature_list = FEATURES.copy() 
    feature_list.append(label)
    
    # Split the dataset into train and validation datasets.
    train_df, valid_df = split_dataset(dataset_df[feature_list])
    # Define the pipeline with default hyperparameter values

    random_state = 42
    # default params
    classifiers = [
        # models
        DummyRegressor(strategy="mean"),
        LinearRegression(),
        Ridge(random_state=random_state),
        Lasso(random_state=random_state),
        ElasticNet(random_state=random_state),
        KernelRidge(),
        SGDRegressor(random_state=random_state),

        LinearSVR(random_state=random_state),
        SVR(kernel="linear", gamma="scale"),
        SVR(kernel="rbf", gamma="scale"),
        SVR(kernel="poly", degree=2, gamma="scale"),
        SVR(kernel="sigmoid", gamma="scale"),

        DecisionTreeRegressor(random_state=random_state),
        RandomForestRegressor(random_state=random_state),

        BaggingRegressor(random_state=random_state),
        AdaBoostRegressor(random_state=random_state),
        ExtraTreesRegressor(random_state=random_state),
        GradientBoostingRegressor(random_state=random_state),
        lgb.LGBMRegressor(random_state=random_state),
        xgb.XGBRegressor(objective="reg:squarederror", random_state=random_state)
        ]

    clf_names = [
        "dummy",
        "linear",
        "ridge",
        "lasso",
        "elastic",
        "kernlrdg",
        "sgdreg",
        "linearsvr",
        "rbfsvr",
        "polysvr",
        "sigmoidsvr", 
        "knnreg"
        "decisiontree",
        "randomforest",
        "baggingreg",
        "adaboostreg",
        "extratreesreg", 
        "gbm", 
        "lgbm", 
        "xgboost"
    ]

    ## testing

    mse_dict = {}
    smape_dict = {}
    pipelines = []
    for clf, name in zip(classifiers, clf_names):
        pipeline = Pipeline([
            ('scaler', StandardScaler()),
            ('model', clf)
        ])
        pipelines.append((name, pipeline))
    # Iterate through each model in the pipeline
    for model_name, pipeline in pipelines:
        print(f'####################################################')
        print(f"Training model: {model_name}")

        # Start the timer
        start_time = time.time()

        # Fit the model on the training data
        pipeline.fit(train_df[FEATURES], train_df[label])
        print(f"Model {model_name} trained.")

        # Calculate the elapsed time
        elapsed_time = time.time() - start_time
        print(f"Training time for model {model_name}: {elapsed_time:.2f} seconds")

        # Make predictions on the validation data
        preds = pipeline.predict(valid_df[FEATURES])

        # Calculate the MSE score
        mse = mean_squared_error(valid_df[label], preds)
        print(f"Model {model_name} MSE score: {mse:.4f}")

        # Calculate the sMAPE score
        smape_score = smape(valid_df[label], preds)
        print(f"Model {model_name} sMAPE score: {smape_score:.4f}")

        # Store the MSE and sMAPE scores in their respective dictionaries
        mse_dict[model_name] = mse
        smape_dict[model_name] = smape_score


    # Store the results in a list of lists
    results = []
    for model_name, mse_score in mse_dict.items():
        results.append([model_name, f"{mse_score:.2f}", f"{smape_dict[model_name]:.2f}"])

    # Define the headers for the table
    headers = ["Model", "MSE", "sMAPE"]

    # Print the table
    results_df = pd.DataFrame(results, columns=headers)

    # Print the DataFrame
    print(results_df)

    # plot smape scores to compare
    smape_df = pd.DataFrame.from_dict(smape_dict, orient='index', columns=['sMAPE'])
    smape_df = smape_df.sort_values(by='sMAPE')

    sns.set(style="whitegrid")
    plt.figure(figsize=(10, 6))
    sns.barplot(x=smape_df.index, y="sMAPE", data=smape_df)
    plt.xlabel('Model')
    plt.ylabel('sMAPE')
    plt.title('sMAPE Scores for Regression Models')
    plt.xticks(rotation=90)
    plt.tight_layout()
    plt.show()
# Out:
# #######################################################
# model updrs_1
# ####################################################
# Training model: dummy
# Model dummy trained.
# Training time for model dummy: 0.03 seconds
# Model dummy MSE score: 28.6632
# Model dummy sMAPE score: 70.9018
# ####################################################
# Training model: linear
# Model linear trained.
# Training time for model linear: 0.29 seconds
# Model linear MSE score: 97.4753
# Model linear sMAPE score: 110.8559
# ####################################################
# Training model: ridge
# Model ridge trained.
# Training time for model ridge: 0.07 seconds
# Model ridge MSE score: 77.7182
# Model ridge sMAPE score: 107.9828
# ####################################################
# Training model: lasso
# Model lasso trained.
# Training time for model lasso: 0.08 seconds
# Model lasso MSE score: 28.5472
# Model lasso sMAPE score: 70.8394
# ####################################################
# ...

# %% [markdown]
# ## PCA

# %% [markdown]
# Trying PCA to improve the accuracy scores

# %%
# do pca on the training set
from sklearn.decomposition import PCA

# Create principal components
pca = PCA()
X_pca = pca.fit_transform(dataset_x)

# Convert to dataframe
component_names = [f"PC{i+1}" for i in range(X_pca.shape[1])]
X_pca = pd.DataFrame(X_pca, columns=component_names)

loadings = pd.DataFrame(
    pca.components_.T,  # transpose the matrix of loadings
    columns=component_names,  # so the columns are the principal components
    index=dataset_x.columns,  # and the rows are the original features
)
loadings
# Out:
#           PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# x1  -0.196003  0.601103 -0.050911  0.118919  0.167622 -0.171605  0.704510
# x3  -0.185755  0.384387 -0.477196  0.088626  0.030405  0.710467 -0.264879
# x4  -0.526408 -0.208285 -0.011403  0.337900 -0.061070  0.010445  0.165699
# x5  -0.134146 -0.004896  0.060412  0.044539 -0.039477 -0.020826 -0.035035
# x6  -0.441053 -0.088039  0.190310 -0.448690  0.276042  0.159641 -0.037669
# x8  -0.414950 -0.231064 -0.172856  0.374025 -0.470582 -0.150625 -0.062543
# x10  0.023628 -0.063467  0.606113  0.559351  0.388495  0.329114 -0.051476
# x13  0.154514 -0.581647 -0.233370 -0.112444  0.060860  0.418715  0.599670
# x14 -0.077570 -0.205900 -0.485005  0.167433  0.712717 -0.364897 -0.187098
# x15  0.484578  0.040471 -0.206762  0.408748 -0.073790  0.016864  0.047233
#
#           PC8       PC9      PC10
# x1   0.037708 -0.167547 -0.012254
# x3  -0.075862 -0.023828 -0.000196
# x4  -0.032020  0.721433  0.111446
# ...

# %%
pca.explained_variance_ratio_
# Out:
# array([0.25343621, 0.17160299, 0.13087467, 0.10807187, 0.10516724,
#        0.0787468 , 0.0587429 , 0.04796749, 0.03219463, 0.01319519])

# %% [markdown]
# 84% variance is described by first 6 PCA components Therefore drop other PCA components and add them to the data set

# %%
pca = PCA(n_components=6)
X_pca = pca.fit_transform(dataset_x)
# Convert to dataframe
component_names = [f"PC{i+1}" for i in range(X_pca.shape[1])]
X_pca = pd.DataFrame(X_pca, columns=component_names, index=dataset_x.index)

# join the principal components to the original data
dataset_x = pd.concat([dataset_x, X_pca], axis=1)

# %%
dataset_x.describe()
# Out:
#                  x1            x3            x4           x5            x6  \
# count  3.265000e+03  3.265000e+03  3.265000e+03  3265.000000  3.265000e+03
# mean  -4.809493e-16  2.344900e-16 -2.992332e-16     0.500225 -3.960759e-16
# std    1.000153e+00  1.000153e+00  1.000153e+00     0.416330  1.000153e+00
# min   -3.164711e+00 -3.253429e+00 -2.805081e+00    -0.183325 -2.927624e+00
# 25%   -6.738788e-01 -6.396919e-01 -7.304143e-01     0.056247 -6.802660e-01
# 50%   -5.117077e-02 -9.516326e-02 -1.174446e-01     0.525493 -2.478661e-02
# 75%    5.715372e-01  6.671768e-01  6.841311e-01     0.860354  6.306927e-01
# max    5.241847e+00  3.770990e+00  3.203790e+00     1.353016  3.463300e+00
#
#                  x8           x10           x13           x14           x15  \
# count  3.265000e+03  3.265000e+03  3.265000e+03  3.265000e+03  3.265000e+03
# mean  -7.508032e-17  2.687658e-16 -1.607154e-15  7.616844e-16  3.035856e-16
# ...

# %%
# do same for the test set
X_pca = pca.fit_transform(df2_x)

# Convert to dataframe
component_names = [f"PC{i+1}" for i in range(X_pca.shape[1])]
X_pca = pd.DataFrame(X_pca, columns=component_names, index=df2_x.index)

loadings = pd.DataFrame(
    pca.components_.T,  # transpose the matrix of loadings
    columns=component_names,  # so the columns are the principal components
    index=df2_x.columns,  # and the rows are the original features
)
loadings
df2_x = pd.concat([df2_x, X_pca], axis=1)

# %%
df2_x.describe()
# Out:
#                 x1           x3           x4           x5           x6  \
# count  1633.000000  1633.000000  1633.000000  1633.000000  1633.000000
# mean     -0.012924    -0.099698     0.013254     0.496015     0.002687
# std       0.938618     0.946686     0.963688     0.401807     1.002110
# min      -2.542003    -2.708901    -2.710778    -0.183747    -2.646704
# 25%      -0.673879    -0.748598    -0.659687     0.074726    -0.680266
# 50%      -0.051171    -0.204069    -0.046717     0.502258    -0.024787
# 75%       0.571537     0.558271     0.684131     0.847329     0.630693
# max       2.751015     2.518574     2.782374     1.311801     2.971690
#
#                 x8          x10          x13          x14          x15  \
# count  1633.000000  1633.000000  1633.000000  1633.000000  1633.000000
# mean      0.053364     0.057097     0.041099     0.010827    -0.037656
# std       1.099210     0.987120     1.037255     1.007674     1.088991
# ...

# %% [markdown]
# # diff model test -- classification

# %% [markdown]
# ## KNN

# %% [markdown]
# First check which k gives highest accuracy

# %%
from sklearn.neighbors import KNeighborsClassifier

k_range = list(range(2,40)) # check for k values from 2 to 40
scores = []

for k in k_range:
    KNN = KNeighborsClassifier(n_neighbors=k)
    KNN.fit(dataset_x, dataset_y)
    y_pred = KNN.predict(df2_x)
    scores.append(accuracy_score(df2_y, y_pred))
    
plt.plot(k_range, scores)
plt.xlabel('Value of k for KNN')
plt.ylabel('Accuracy Score')
plt.title('Accuracy Scores vs k of KNN')

d = {'best features number': range(2,40), 'train_score': scores}
df = pd.DataFrame(data=d)
print("max accuracy:",df["train_score"].max())
print("max accuracy k:",df["train_score"].idxmax())
# Out:
# max accuracy: 0.4127372933251684
# max accuracy k: 35

# %%
from sklearn.neighbors import KNeighborsClassifier

KNN = KNeighborsClassifier(n_neighbors=35)
KNN.fit(dataset_x, dataset_y)

y_test_pred = KNN.predict(df2_x)
y_train_pred = KNN.predict(dataset_x)

scores = cross_val_score(KNN, dataset_x , dataset_y , cv = 10, scoring = 'accuracy' )
conf = confusion_matrix(df2_y, y_test_pred)

print("\n************************************************")
print("Tain set Accuracy: ", accuracy_score(dataset_y, y_train_pred))
print("Test set Accuracy: ", accuracy_score(df2_y, y_test_pred))
print("cv(cross validation score):  %s\n"% scores.mean())
print("************************************************")
print("precision_score: ", precision_score(df2_y, y_test_pred, average='weighted'))
print("recall_score: ", recall_score(df2_y, y_test_pred, average='weighted'))
print("f1_score: ", f1_score(df2_y, y_test_pred, average='weighted'))
print("************************************************")
# Out:
# ************************************************
# Tain set Accuracy:  0.5705972434915774
# Test set Accuracy:  0.41212492345376606
# cv(cross validation score):  0.5378248062888126
#
# ************************************************
# precision_score:  0.34649511909153097
# recall_score:  0.41212492345376606
# f1_score:  0.3587572617050731
# ************************************************

# %% [markdown]
# ## decision trees

# %%
from sklearn.tree import DecisionTreeClassifier

DT = DecisionTreeClassifier()
DT.fit(dataset_x, dataset_y)

y_test_pred = DT.predict(df2_x)
y_train_pred = DT.predict(dataset_x)

scores = cross_val_score(DT, dataset_x , dataset_y , cv = 10, scoring = 'accuracy' )
conf = confusion_matrix(df2_y, y_test_pred)

print("\n************************************************")
print("Tain set Accuracy: ", accuracy_score(dataset_y, y_train_pred))
print("Test set Accuracy: ", accuracy_score(df2_y, y_test_pred))
print("cv(cross validation score):  %s\n"% scores.mean())
print("************************************************")
print("precision_score: ", precision_score(df2_y, y_test_pred, average='weighted'))
print("recall_score: ", recall_score(df2_y, y_test_pred, average='weighted'))
print("f1_score: ", f1_score(df2_y, y_test_pred, average='weighted'))
print("************************************************")
# Out:
# ************************************************
# Tain set Accuracy:  1.0
# Test set Accuracy:  0.3104715248009798
# cv(cross validation score):  0.5626310951014052
#
# ************************************************
# precision_score:  0.3182888609411098
# recall_score:  0.3104715248009798
# f1_score:  0.3138326890223683
# ************************************************

# %% [markdown]
# Hyperparameter tuning

# %%
# use gridsearchCV to find the best parameters
# max_depth, min_samples_split, min_samples_leaf
grid_search = GridSearchCV(DecisionTreeClassifier(), param_grid={'max_depth': range(1, 10), 
                                                                 'min_samples_split': range(2, 10), 
                                                                 'min_samples_leaf': range(1, 10)}, cv=10, scoring='accuracy')
grid_search.fit(dataset_x, dataset_y)
print(grid_search.best_params_)
# Out:
# {'max_depth': 9, 'min_samples_leaf': 1, 'min_samples_split': 4}

# %%
# even though above results say to use max_depth=9, min_samples_split=1, min_samples_leaf=4
# with trial and error, I found that max_depth=2, min_samples_split=7, min_samples_leaf=4 gives the best results in terms of both accuracy and cross-validation score
DT = DecisionTreeClassifier(max_depth= 2, min_samples_leaf= 7, min_samples_split=4)
DT.fit(dataset_x, dataset_y)

y_test_pred = DT.predict(df2_x)
y_train_pred = DT.predict(dataset_x)

scores = cross_val_score(DT, dataset_x , dataset_y , cv = 10, scoring = 'accuracy' )
conf = confusion_matrix(df2_y, y_test_pred)

print("\n************************************************")
print("Tain set Accuracy: ", accuracy_score(dataset_y, y_train_pred))
print("Test set Accuracy: ", accuracy_score(df2_y, y_test_pred))
print("cv(cross validation score):  %s\n"% scores.mean())
print("************************************************")
print("precision_score: ", precision_score(df2_y, y_test_pred, average='weighted'))
print("recall_score: ", recall_score(df2_y, y_test_pred, average='weighted'))
print("f1_score: ", f1_score(df2_y, y_test_pred, average='weighted'))
print("************************************************")
# Out:
# ************************************************
# Tain set Accuracy:  0.5228177641653905
# Test set Accuracy:  0.40722596448254744
# cv(cross validation score):  0.5160869402075007
#
# ************************************************
# precision_score:  0.2909972299919346
# recall_score:  0.40722596448254744
# f1_score:  0.33532665092509406
# ************************************************

# %% [markdown]
# ## Extra trees classifier

# %%
from sklearn.ensemble import ExtraTreesClassifier, GradientBoostingClassifier, StackingClassifier, RandomForestClassifier
ET = ExtraTreesClassifier(random_state=0)
ET.fit(dataset_x, dataset_y)

y_test_pred = ET.predict(df2_x)
y_train_pred = ET.predict(dataset_x)

scores = cross_val_score(ET, dataset_x , dataset_y , cv = 10, scoring = 'accuracy' )
conf = confusion_matrix(df2_y, y_test_pred)

print("\n************************************************")
print("Tain set Accuracy: ", accuracy_score(dataset_y, y_train_pred))
print("Test set Accuracy: ", accuracy_score(df2_y, y_test_pred))
print("cv(cross validation score):  %s\n"% scores.mean())
print("************************************************")
print("precision_score: ", precision_score(df2_y, y_test_pred, average='weighted'))
print("recall_score: ", recall_score(df2_y, y_test_pred, average='weighted'))
print("f1_score: ", f1_score(df2_y, y_test_pred, average='weighted'))
print("************************************************")
# Out:
# ************************************************
# Tain set Accuracy:  1.0
# Test set Accuracy:  0.40477648499693814
# cv(cross validation score):  0.6658636798559125
#
# ************************************************
# precision_score:  0.3457121463353325
# recall_score:  0.40477648499693814
# f1_score:  0.3640857876375165
# ************************************************

# %% [markdown]
# For hyperparameter tunning, with trial and error found that following settings give the maximum score

# %%
ET = ExtraTreesClassifier(max_depth=2, min_samples_leaf=7, min_samples_split=2,
                     n_estimators=200, random_state=0)
ET.fit(dataset_x, dataset_y)

y_test_pred = ET.predict(df2_x)
y_train_pred = ET.predict(dataset_x)

scores = cross_val_score(ET, dataset_x , dataset_y , cv = 10, scoring = 'accuracy' )
conf = confusion_matrix(df2_y, y_test_pred)

print("\n************************************************")
print("Tain set Accuracy: ", accuracy_score(dataset_y, y_train_pred))
print("Test set Accuracy: ", accuracy_score(df2_y, y_test_pred))
print("cv(cross validation score):  %s\n"% scores.mean())
print("************************************************")
print("precision_score: ", precision_score(df2_y, y_test_pred, average='weighted'))
print("recall_score: ", recall_score(df2_y, y_test_pred, average='weighted'))
print("f1_score: ", f1_score(df2_y, y_test_pred, average='weighted'))
print("************************************************")
# Out:
# ************************************************
# Tain set Accuracy:  0.4652373660030628
# Test set Accuracy:  0.43600734843845684
# cv(cross validation score):  0.4634003114388099
#
# ************************************************
# precision_score:  0.3010702555252463
# recall_score:  0.43600734843845684
# f1_score:  0.2783059113755692
# ************************************************

# %% [markdown]
# ## logistic regression

# %%
from sklearn.linear_model import LogisticRegression

LR = LogisticRegression()
LR.fit(dataset_x, dataset_y)

y_test_pred = LR.predict(df2_x)
y_train_pred = LR.predict(dataset_x)

scores = cross_val_score(ET, dataset_x , dataset_y , cv = 10, scoring = 'accuracy' )
conf = confusion_matrix(df2_y, y_test_pred)

print("\n************************************************")
print("Tain set Accuracy: ", accuracy_score(dataset_y, y_train_pred))
print("Test set Accuracy: ", accuracy_score(df2_y, y_test_pred))
print("cv(cross validation score):  %s\n"% scores.mean())
print("************************************************")
print("precision_score: ", precision_score(df2_y, y_test_pred, average='weighted'))
print("recall_score: ", recall_score(df2_y, y_test_pred, average='weighted'))
print("f1_score: ", f1_score(df2_y, y_test_pred, average='weighted'))
print("************************************************")
# Out:
# ************************************************
# Tain set Accuracy:  0.5393568147013783
# Test set Accuracy:  0.40171463563992654
# cv(cross validation score):  0.5050552522466746
#
# ************************************************
# precision_score:  0.3355669804992638
# recall_score:  0.40171463563992654
# f1_score:  0.35395867781654383
# ************************************************

# %% [markdown]
# ## XGBoost

# %%
# encode target labels with value between 0 and n_classes-1 for xgboost
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
dataset_y= le.fit_transform(dataset_y)
df2_y= le.transform(df2_y)

# %%
from xgboost import XGBClassifier
from hyperopt import hp, Trials, fmin, tpe, STATUS_OK, space_eval


xgb = XGBClassifier()
xgb.fit(dataset_x, dataset_y)

y_test_pred = xgb.predict(df2_x)
y_train_pred = xgb.predict(dataset_x)

scores = cross_val_score(xgb, dataset_x , dataset_y , cv = 10, scoring = 'accuracy' )
conf = confusion_matrix(df2_y, y_test_pred)

print("\n************************************************")
print("Tain set Accuracy: ", accuracy_score(dataset_y, y_train_pred))
print("Test set Accuracy: ", accuracy_score(df2_y, y_test_pred))
print("cv(cross validation score):  %s\n"% scores.mean())
print("************************************************")
print("precision_score: ", precision_score(df2_y, y_test_pred, average='weighted'))
print("recall_score: ", recall_score(df2_y, y_test_pred, average='weighted'))
print("f1_score: ", f1_score(df2_y, y_test_pred, average='weighted'))
print("************************************************")
# Out:
# ************************************************
# Tain set Accuracy:  0.9996937212863706
# Test set Accuracy:  0.38946723821187995
# cv(cross validation score):  0.6490234704789779
#
# ************************************************
# precision_score:  0.34330650008822394
# recall_score:  0.38946723821187995
# f1_score:  0.3593541671470561
# ************************************************

# %% [markdown]
# Hyperparameter tunning

# %%
space={'max_depth': hp.quniform("max_depth", 3, 18, 1),
        'gamma': hp.uniform ('gamma', 1,9),
        'reg_alpha' : hp.quniform('reg_alpha', 40,180,1),
        'reg_lambda' : hp.uniform('reg_lambda', 0,1),
        'colsample_bytree' : hp.uniform('colsample_bytree', 0.5,1),
        'min_child_weight' : hp.quniform('min_child_weight', 0, 10, 1),
        'n_estimators': 180,
        'seed': 0
    }
def objective(space):
    clf=XGBClassifier(
                    n_estimators =space['n_estimators'], max_depth = int(space['max_depth']), gamma = space['gamma'],
                    reg_alpha = int(space['reg_alpha']),min_child_weight=int(space['min_child_weight']),
                    colsample_bytree=int(space['colsample_bytree']))
    
    evaluation = [( dataset_x,dataset_y), ( df2_x,df2_y)]
    
    clf.fit(dataset_x,dataset_y,
            eval_set=evaluation, eval_metric="auc",
            early_stopping_rounds=10,verbose=False)
    

    pred = clf.predict(df2_x)
    accuracy = accuracy_score(df2_y, pred>0.5)
    print ("SCORE:", accuracy)
    return {'loss': -accuracy, 'status': STATUS_OK }

# %%
trials = Trials()

best_hyperparams = fmin(fn = objective,
                        space = space,
                        algo = tpe.suggest,
                        max_evals = 100,
                        trials = trials)
# Out:
# SCORE:
# 0.03674219228413962
# SCORE:
# 0.03674219228413962
# SCORE:
# 0.03674219228413962
# SCORE:
# 0.03674219228413962
# SCORE:
# 0.03674219228413962
# SCORE:
# 0.03674219228413962
# SCORE:
# 0.03674219228413962
# SCORE:
# 0.03674219228413962
# SCORE:
# 0.03674219228413962
# SCORE:
# 0.03674219228413962
# SCORE:
# 0.03674219228413962
# SCORE:
# 0.03674219228413962
# SCORE:
# 0.03674219228413962
# SCORE:
# 0.03674219228413962
# SCORE:
# 0.03674219228413962
# SCORE:
# 0.03674219228413962
# SCORE:
# 0.03674219228413962
# SCORE:
# 0.03674219228413962
# SCORE:
# 0.03674219228413962
# SCORE:
# 0.03674219228413962
# SCORE:
# 0.03674219228413962
# SCORE:
# 0.03674219228413962
# SCORE:
# 0.03674219228413962
# SCORE:
# 0.03674219228413962
# SCORE:
# 0.03674219228413962
# SCORE:
# 0.03674219228413962
# SCORE:
# 0.03674219228413962
# SCORE:
# 0.03674219228413962
# SCORE:
# 0.03674219228413962
# SCORE:
# 0.03674219228413962
# SCORE:
# 0.03674219228413962
# SCORE:
# 0.03674219228413962
# ...

# %%
print("The best hyperparameters are : ","\n")
print(best_hyperparams)
# Out:
# The best hyperparameters are :
#
# {'colsample_bytree': 0.8872044276786306, 'gamma': 6.7476640925150395, 'max_depth': 7.0, 'min_child_weight': 6.0, 'reg_alpha': 97.0, 'reg_lambda': 0.8437305827134567}

# %%
from xgboost import XGBClassifier
from hyperopt import hp, Trials, fmin, tpe, STATUS_OK, space_eval


xgb = XGBClassifier(n_estimators=100,colsample_bytree= 0.8872044276786306, gamma= 6.7476640925150395, max_depth=7,min_child_weight=6.0, reg_alpha= 97.0, reg_lambda= 0.8437305827134567)
xgb.fit(dataset_x, dataset_y)

y_test_pred = xgb.predict(df2_x)
y_train_pred = xgb.predict(dataset_x)

scores = cross_val_score(xgb, dataset_x , dataset_y , cv = 10, scoring = 'accuracy' )
conf = confusion_matrix(df2_y, y_test_pred)

print("\n************************************************")
print("Tain set Accuracy: ", accuracy_score(dataset_y, y_train_pred))
print("Test set Accuracy: ", accuracy_score(df2_y, y_test_pred))
print("cv(cross validation score):  %s\n"% scores.mean())
print("************************************************")
print("precision_score: ", precision_score(df2_y, y_test_pred, average='weighted'))
print("recall_score: ", recall_score(df2_y, y_test_pred, average='weighted'))
print("f1_score: ", f1_score(df2_y, y_test_pred, average='weighted'))
print("************************************************")
# Out:
# ************************************************
# Tain set Accuracy:  0.5295558958652373
# Test set Accuracy:  0.4078383343539498
# cv(cross validation score):  0.5286467420873906
#
# ************************************************
# precision_score:  0.32271998271872393
# recall_score:  0.4078383343539498
# f1_score:  0.3429016176806009
# ************************************************

# %% [markdown]
# ## MLP classifier

# %%
from sklearn.neural_network import MLPClassifier

MLP = MLPClassifier(hidden_layer_sizes=10, learning_rate_init=0.1, random_state=0,
              solver='sgd')
MLP.fit(dataset_x, dataset_y)

y_test_pred = MLP.predict(df2_x)
y_train_pred = MLP.predict(dataset_x)

scores = cross_val_score(MLP, dataset_x , dataset_y , cv = 10, scoring = 'accuracy' )
conf = confusion_matrix(df2_y, y_test_pred)

print("\n************************************************")
print("Tain set Accuracy: ", accuracy_score(dataset_y, y_train_pred))
print("Test set Accuracy: ", accuracy_score(df2_y, y_test_pred))
print("cv(cross validation score):  %s\n"% scores.mean())
print("************************************************")
print("precision_score: ", precision_score(df2_y, y_test_pred, average='weighted'))
print("recall_score: ", recall_score(df2_y, y_test_pred, average='weighted'))
print("f1_score: ", f1_score(df2_y, y_test_pred, average='weighted'))
print("************************************************")
# Out:
# ************************************************
# Tain set Accuracy:  0.5672281776416539
# Test set Accuracy:  0.37783221065523576
# cv(cross validation score):  0.5451680081049136
#
# ************************************************
# precision_score:  0.3210656911268031
# recall_score:  0.37783221065523576
# f1_score:  0.3366631290618763
# ************************************************

# %% [markdown]
# ## Gradient boosting classifier

# %%
GB = GradientBoostingClassifier(criterion='squared_error',
                           min_samples_leaf=4, min_samples_split=6,
                           n_estimators=25, random_state=0)
GB.fit(dataset_x, dataset_y)

y_test_pred = GB.predict(df2_x)
y_train_pred = GB.predict(dataset_x)

scores = cross_val_score(GB, dataset_x , dataset_y , cv = 10, scoring = 'accuracy' )
conf = confusion_matrix(df2_y, y_test_pred)

print("\n************************************************")
print("Tain set Accuracy: ", accuracy_score(dataset_y, y_train_pred))
print("Test set Accuracy: ", accuracy_score(df2_y, y_test_pred))
print("cv(cross validation score):  %s\n"% scores.mean())
print("************************************************")
print("precision_score: ", precision_score(df2_y, y_test_pred, average='weighted'))
print("recall_score: ", recall_score(df2_y, y_test_pred, average='weighted'))
print("f1_score: ", f1_score(df2_y, y_test_pred, average='weighted'))
print("************************************************")
# Out:
# ************************************************
# Tain set Accuracy:  0.6330781010719755
# Test set Accuracy:  0.387630128597673
# cv(cross validation score):  0.5555974559576743
#
# ************************************************
# precision_score:  0.3379481394491769
# recall_score:  0.387630128597673
# f1_score:  0.3540155083337376
# ************************************************

# %% [markdown]
# ## Random forest

# %%
RF = RandomForestClassifier(criterion='entropy', min_samples_leaf=2, n_estimators=25,
                       random_state=0)

RF.fit(dataset_x, dataset_y)

y_test_pred = RF.predict(df2_x)
y_train_pred = RF.predict(dataset_x)

scores = cross_val_score(RF, dataset_x , dataset_y , cv = 10, scoring = 'accuracy' )
conf = confusion_matrix(df2_y, y_test_pred)

print("\n************************************************")
print("Tain set Accuracy: ", accuracy_score(dataset_y, y_train_pred))
print("Test set Accuracy: ", accuracy_score(df2_y, y_test_pred))
print("cv(cross validation score):  %s\n"% scores.mean())
print("************************************************")
print("precision_score: ", precision_score(df2_y, y_test_pred, average='weighted'))
print("recall_score: ", recall_score(df2_y, y_test_pred, average='weighted'))
print("f1_score: ", f1_score(df2_y, y_test_pred, average='weighted'))
print("************************************************")
# Out:
# ************************************************
# Tain set Accuracy:  0.9816232771822359
# Test set Accuracy:  0.3949785670545009
# cv(cross validation score):  0.636764788653121
#
# ************************************************
# precision_score:  0.3368680734214517
# recall_score:  0.3949785670545009
# f1_score:  0.3563244874290483
# ************************************************

# %% [markdown]
# ## stacking classifier

# %%
estimators = [('DT', DT),
              ('RF', RF),
              ('MLP', MLP),
              ('ET', ET),
              ('LR', LR),
              ('KNN', KNN),
              ('GB', GB),
              ('xgb', xgb)
             ]

SC_tune_LR = StackingClassifier(estimators = estimators,)
SC_tune_LR.fit(dataset_x, dataset_y)

y_test_pred = SC_tune_LR.predict(df2_x)
y_train_pred = SC_tune_LR.predict(dataset_x)

scores = cross_val_score(SC_tune_LR, dataset_x , dataset_y , cv = 10, scoring = 'accuracy' )
conf = confusion_matrix(df2_y, y_test_pred)

print("\n************************************************")
print("Tain set Accuracy: ", accuracy_score(dataset_y, y_train_pred))
print("Test set Accuracy: ", accuracy_score(df2_y, y_test_pred))
print("cv(cross validation score):  %s\n"% scores.mean())
print("************************************************")
print("precision_score: ", precision_score(df2_y, y_test_pred, average='weighted'))
print("recall_score: ", recall_score(df2_y, y_test_pred, average='weighted'))
print("f1_score: ", f1_score(df2_y, y_test_pred, average='weighted'))
print("************************************************")
# Out:
# ************************************************
# Tain set Accuracy:  0.9586523736600306
# Test set Accuracy:  0.39436619718309857
# cv(cross validation score):  0.6358482955291646
#
# ************************************************
# precision_score:  0.34256434475233416
# recall_score:  0.39436619718309857
# f1_score:  0.3601994724863039
# ************************************************

# %% [markdown]
# # Final conclusions

# %% [markdown]
# It is clear that non of the models seems to give accuracy scores close to 100%
# The highest accuracy is achieved with the *Extra tree classifier* with nearly 44% accuracy score
#
# ************************************************
# Tain set Accuracy:  0.4652373660030628
# Test set Accuracy:  0.43600734843845684
# cv(cross validation score):  0.4634003114388099
#
# ************************************************
# Other significant models with decreasing scores are,
#
# ## KNN
#
# ************************************************
# Tain set Accuracy:  0.5705972434915774
# Test set Accuracy:  0.41212492345376606
# cv(cross validation score):  0.5378248062888126
#
# ************************************************
#
# ## XGBoost
#
# ************************************************
# Tain set Accuracy:  0.5295558958652373
# Test set Accuracy:  0.4078383343539498
# cv(cross validation score):  0.5286467420873906
#
# ************************************************
#
# ## Decision trees
#
# ************************************************
# Tain set Accuracy:  0.5228177641653905
# Test set Accuracy:  0.40722596448254744
# cv(cross validation score):  0.5160869402075007
#
# ************************************************
#
# ## Logistic regression
#
# ************************************************
# Tain set Accuracy:  0.5393568147013783
# Test set Accuracy:  0.40171463563992654
# cv(cross validation score):  0.5050552522466746
#
# ************************************************

# %% [markdown]
# The following patterns of the data set affects the low accuracy scores
# Most of the samples are given for the outcome 6 and very little data is given for the 3 and 9 outcomes,
# hence our models barely predicts these values of the test sets
#
# Therefore upsampling of categories with lower prediction categories will increase the accuracy score even more,
# Furthermore, it is to be noted that our model is better than a model with pure chance which is 1/7 categories = 7%

# %%
sns.histplot(df2_y)
# Out:
# <Axes: xlabel='y', ylabel='Count'>

# %%
sns.histplot(y_test_pred)
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# # Submission

# %%
#join dataset_x and dataset_y
dataset_x.describe()
# Out:
#                  x1            x3            x4           x5            x6  \
# count  3.265000e+03  3.265000e+03  3.265000e+03  3265.000000  3.265000e+03
# mean  -4.809493e-16  2.344900e-16 -2.992332e-16     0.500225 -3.960759e-16
# std    1.000153e+00  1.000153e+00  1.000153e+00     0.416330  1.000153e+00
# min   -3.164711e+00 -3.253429e+00 -2.805081e+00    -0.183325 -2.927624e+00
# 25%   -6.738788e-01 -6.396919e-01 -7.304143e-01     0.056247 -6.802660e-01
# 50%   -5.117077e-02 -9.516326e-02 -1.174446e-01     0.525493 -2.478661e-02
# 75%    5.715372e-01  6.671768e-01  6.841311e-01     0.860354  6.306927e-01
# max    5.241847e+00  3.770990e+00  3.203790e+00     1.353016  3.463300e+00
#
#                  x8           x10           x13           x14           x15  \
# count  3.265000e+03  3.265000e+03  3.265000e+03  3.265000e+03  3.265000e+03
# mean  -7.508032e-17  2.687658e-16 -1.607154e-15  7.616844e-16  3.035856e-16
# ...

# %%
# turn dataset_y into a dataframe
dataset_y = pd.DataFrame(dataset_y,columns=['y'])
df2_y = pd.DataFrame(df2_y,columns=['y'])
dataset_y.describe()
# Out:
#                  y
# count  3265.000000
# mean      2.887289
# std       0.885705
# min       0.000000
# 25%       2.000000
# 50%       3.000000
# 75%       3.000000
# max       6.000000

# %%
dataset_out = pd.concat([dataset_x,dataset_y],axis=1) 
df2_out = pd.concat([df2_x,df2_y],axis=1)

# %%
df2_out.describe()
# Out:
#                 x1           x3           x4           x5           x6  \
# count  1633.000000  1633.000000  1633.000000  1633.000000  1633.000000
# mean     -0.012924    -0.099698     0.013254     0.496015     0.002687
# std       0.938618     0.946686     0.963688     0.401807     1.002110
# min      -2.542003    -2.708901    -2.710778    -0.183747    -2.646704
# 25%      -0.673879    -0.748598    -0.659687     0.074726    -0.680266
# 50%      -0.051171    -0.204069    -0.046717     0.502258    -0.024787
# 75%       0.571537     0.558271     0.684131     0.847329     0.630693
# max       2.751015     2.518574     2.782374     1.311801     2.971690
#
#                 x8          x10          x13          x14          x15  \
# count  1633.000000  1633.000000  1633.000000  1633.000000  1633.000000
# mean      0.053364     0.057097     0.041099     0.010827    -0.037656
# std       1.099210     0.987120     1.037255     1.007674     1.088991
# ...

# %%
dataset_out = df1.copy()
dataset_out.to_csv('Kickstarter_cleaned.csv',index=False)
# df2_out.to_csv('200694G_lab1_test.csv',index=False)
print("Output files created")
# Out:
# Output files created
